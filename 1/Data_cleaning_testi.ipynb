# %%
import pandas as pd
import numpy as np

data = pd.read_csv('https://raw.githubusercontent.com/NikoLaaks/Analysoinnin-perusteet/main/1/athlete_events.csv')
data.head()

missing_count = data.isnull().sum()
print(missing_count)

pituus_puuttuvat = (data['Height'].isnull().sum())
pituus = len(data['Name'])

print(pituus, pituus_puuttuvat)
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64
# 271116 60171

# %%
data.sort_values(["Height"], ascending=[True] )
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 164821   82769            Lyton Levison Mphande   M  25.0   127.0    62.0
# 29338    15150                  Rosario Briones   F  15.0   127.0    42.0
# 29337    15150                  Rosario Briones   F  15.0   127.0    42.0
# 29336    15150                  Rosario Briones   F  15.0   127.0    42.0
# 29335    15150                  Rosario Briones   F  15.0   127.0    42.0
# ...        ...                              ...  ..   ...     ...     ...
# 271038  135539            Marius Edmund Zwiller   M  18.0     NaN     NaN
# 271042  135542                   Werner Zwingli   M  29.0     NaN     NaN
# 271043  135542                   Werner Zwingli   M  29.0     NaN     NaN
# 271075  135552  Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 271100  135561                    Frantiek Zyka   M  26.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season               City  \
# ...

# %%
average_age = np.mean(data['Age'])
print(round(average_age))
# Out:
# 26

# %%
values = {'Age': 26}
data1 = data.fillna(value=values)

# %%
missing_count = data1.isnull().sum()
print(missing_count)
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64
